# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read train dataset
data = pd.read_csv("train.csv", sep = ";")
#Read test dataset
test = pd.read_csv("test.csv", sep = ";")
ctest = pd.read_csv("checktest.csv")

# %%
tp = test['type']
idt = test['id']
test = test.drop('id', axis = 1)
test = test.drop('type', axis = 1)
test['quality'] = ctest
test['type'] = tp

# %%
data = data.drop_duplicates()

# %%
data = data.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')

# %%
data
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            6.6               0.3         0.36             1.2
# 1         1            7.7               0.5         0.26             1.9
# 2         2            8.4               0.5         0.35             2.9
# 3         3            7.5               0.4         0.33             5.0
# 4         4            6.4               0.2         0.25            20.2
# ...     ...            ...               ...          ...             ...
# 5610   6708            7.1               0.5         0.03             2.6
# 5611   6709            7.2               0.2         0.19             7.7
# 5612   6710            6.7               0.3         0.34             7.5
# 5613   6712            8.0               0.2         0.31             5.6
# 5614   6713            6.4               0.3         0.20            15.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
test.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.148090     0.404987
# volatile acidity           0.148090          1.000000    -0.432103
# citric acid                0.404987         -0.432103     1.000000
# residual sugar            -0.076026         -0.195162     0.195910
# chlorides                  0.277601          0.344942     0.090382
# free sulfur dioxide       -0.309198         -0.342195     0.105643
# total sulfur dioxide      -0.332884         -0.444316     0.184849
# density                    0.473337          0.235538     0.200611
# pH                        -0.319967          0.267446    -0.396229
# sulphates                  0.218000          0.254487     0.024964
# alcohol                   -0.072890          0.072352    -0.111944
# quality                   -0.151072         -0.264250     0.067934
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
data.corr()
# Out:
#                          index  fixed acidity  volatile acidity  citric acid  \
# index                 1.000000       0.003449          0.027327     0.023956
# fixed acidity         0.003449       1.000000          0.222300     0.324821
# volatile acidity      0.027327       0.222300          1.000000    -0.382831
# citric acid           0.023956       0.324821         -0.382831     1.000000
# residual sugar       -0.037421      -0.119277         -0.184091     0.144874
# chlorides             0.047855       0.291713          0.357989     0.062208
# free sulfur dioxide  -0.005808      -0.297059         -0.363261     0.140738
# total sulfur dioxide -0.016740      -0.345554         -0.411236     0.200662
# density              -0.006249       0.497355          0.323465     0.082030
# pH                    0.031859      -0.251559          0.256932    -0.346863
# sulphates             0.017628       0.343154          0.235662     0.074837
# ...

# %%
#remove outliers
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
liststr = {'fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide',
           'total sulfur dioxide','density','pH','sulphates','alcohol'}
for feature in liststr:
    upper_limit = data[feature].mean() + 5*data[feature].std()
    lower_limit = data[feature].mean() - 5*data[feature].std()
    
    # Remove the outliers, if any were specified
    data = data.loc[(data[feature] <= upper_limit) & (data[feature] >= lower_limit)]

# %%
data = data.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
data
# Out:
#       level_0  index  fixed acidity  volatile acidity  citric acid  \
# 0           0      0            6.6               0.3         0.36
# 1           1      1            7.7               0.5         0.26
# 2           2      2            8.4               0.5         0.35
# 3           3      3            7.5               0.4         0.33
# 4           4      4            6.4               0.2         0.25
# ...       ...    ...            ...               ...          ...
# 5537     5610   6708            7.1               0.5         0.03
# 5538     5611   6709            7.2               0.2         0.19
# 5539     5612   6710            6.7               0.3         0.34
# 5540     5613   6712            8.0               0.2         0.31
# 5541     5614   6713            6.4               0.3         0.20
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.2      0.035                   43                   126
# ...

# %%
data.corr()
# Out:
#                        level_0     index  fixed acidity  volatile acidity  \
# level_0               1.000000  0.998929       0.004136          0.026321
# index                 0.998929  1.000000       0.004631          0.025948
# fixed acidity         0.004136  0.004631       1.000000          0.224076
# volatile acidity      0.026321  0.025948       0.224076          1.000000
# citric acid           0.017413  0.018513       0.320401         -0.399434
# residual sugar       -0.034782 -0.035699      -0.118937         -0.193224
# chlorides             0.031883  0.032674       0.357564          0.444007
# free sulfur dioxide  -0.005944 -0.006060      -0.300986         -0.368488
# total sulfur dioxide -0.013403 -0.013583      -0.342250         -0.412511
# density              -0.005219 -0.005504       0.502491          0.320278
# pH                    0.031133  0.030894      -0.241152          0.267760
# sulphates             0.017553  0.017960       0.348836          0.232548
# ...

# %%
# fixed acidity
# free sulfur dioxide
# residual sugar
# alcohol

# %%
alc_d = data['alcohol']
alc_t = test['alcohol']
a = pd.read_csv("a.csv")
b = pd.read_csv("b.csv")
j = 0
for i in alc_d:
    if(i >0 and i <= 0.9):
        a.loc[j] =[1010]
        j = j+1
    if(i > 0.9 and i <= 1.6):
        a.loc[j] =[1015]
        j = j+1
    if(i > 1.6 and i <= 2.3):
        a.loc[j] =[1020]
        j = j+1
    if(i > 2.3 and i <= 3.0):
        a.loc[j] =[1025]
        j = j+1
    if(i > 3.0 and i <= 3.7):
        a.loc[j] =[1030]
        j = j+1
    if(i > 3.7 and i <= 4.4):
        a.loc[j] =[1035]
        j = j+1
    if(i > 4.4 and i <= 5.1):
        a.loc[j] =[1040]
        j = j+1
    if(i > 5.1 and i <= 5.8):
        a.loc[j] =[1045]
        j = j+1
    if(i > 5.8 and i <= 6.5):
        a.loc[j] =[1050]
        j = j+1
    if(i > 6.5 and i <= 7.2):
        a.loc[j] =[1055]
        j = j+1
    if(i > 7.2 and i <= 7.8):
        a.loc[j] =[1060]
        j = j+1
    if(i > 7.8 and i <= 8.6):
        a.loc[j] =[1065]
        j = j+1
    if(i > 8.6 and i <= 9.2):
        a.loc[j] =[1070]
        j = j+1
    if(i > 9.2 and i <= 9.9):
        a.loc[j] =[1075]
        j = j+1
    if(i > 9.9 and i <= 10.6):
        a.loc[j] =[1080]
        j = j+1
    if(i > 10.6 and i <= 11.3):
        a.loc[j] =[1085]
        j = j+1
    if(i > 11.3 and i <= 12.0):
        a.loc[j] =[1090]
        j = j+1
    if(i > 12.0 and i <= 12.7):
        a.loc[j] =[1095]
        j = j+1
    if(i > 12.7 and i <= 13.4):
        a.loc[j] =[1100]
        j = j+1
    if(i > 13.4 and i <= 14.1):
        a.loc[j] =[1105]
        j = j+1
    if(i > 14.1 and i <= 14.9):
        a.loc[j] =[1110]
        j = j+1
    if(i > 14.9 and i <= 15.6):
        a.loc[j] =[1115]
        j = j+1
    if(i > 15.6 and i <= 16.3):
        a.loc[j] =[1120]
        j = j+1
    if(i > 16.3 and i <= 17):
        a.loc[j] =[1125]
        j = j+1
    if(i > 17 and i <= 17.7):
        a.loc[j] =[1130]
        j = j+1
    if(i > 17.7 and i <= 18.4):
        a.loc[j] =[1135]
        j = j+1
j=0
for i in alc_t:
    if(i >0 and i <= 0.9):
        b.loc[j] =[1010]
        j = j+1
    if(i > 0.9 and i <= 1.6):
        b.loc[j] =[1015]
        j = j+1
    if(i > 1.6 and i <= 2.3):
        b.loc[j] =[1020]
        j = j+1
    if(i > 2.3 and i <= 3.0):
        b.loc[j] =[1025]
        j = j+1
    if(i > 3.0 and i <= 3.7):
        b.loc[j] =[1030]
        j = j+1
    if(i > 3.7 and i <= 4.4):
        b.loc[j] =[1035]
        j = j+1
    if(i > 4.4 and i <= 5.1):
        b.loc[j] =[1040]
        j = j+1
    if(i > 5.1 and i <= 5.8):
        b.loc[j] =[1045]
        j = j+1
    if(i > 5.8 and i <= 6.5):
        b.loc[j] =[1050]
        j = j+1
    if(i > 6.5 and i <= 7.2):
        b.loc[j] =[1055]
        j = j+1
    if(i > 7.2 and i <= 7.8):
        b.loc[j] =[1060]
        j = j+1
    if(i > 7.8 and i <= 8.6):
        b.loc[j] =[1065]
        j = j+1
    if(i > 8.6 and i <= 9.2):
        b.loc[j] =[1070]
        j = j+1
    if(i > 9.2 and i <= 9.9):
        b.loc[j] =[1075]
        j = j+1
    if(i > 9.9 and i <= 10.6):
        b.loc[j] =[1080]
        j = j+1
    if(i > 10.6 and i <= 11.3):
        b.loc[j] =[1085]
        j = j+1
    if(i > 11.3 and i <= 12.0):
        b.loc[j] =[1090]
        j = j+1
    if(i > 12.0 and i <= 12.7):
        b.loc[j] =[1095]
        j = j+1
    if(i > 12.7 and i <= 13.4):
        b.loc[j] =[1100]
        j = j+1
    if(i > 13.4 and i <= 14.1):
        b.loc[j] =[1105]
        j = j+1
    if(i > 14.1 and i <= 14.9):
        b.loc[j] =[1110]
        j = j+1
    if(i > 14.9 and i <= 15.6):
        b.loc[j] =[1115]
        j = j+1
    if(i > 15.6 and i <= 16.3):
        b.loc[j] =[1120]
        j = j+1
    if(i > 16.3 and i <= 17):
        b.loc[j] =[1125]
        j = j+1
    if(i > 17 and i <= 17.7):
        b.loc[j] =[1130]
        j = j+1
    if(i > 17.7 and i <= 18.4):
        b.loc[j] =[1135]
        j = j+1

# %%
# brix_d = pd.DataFrame()
# brix_d['brix'] = brix_d
# free_d = data['free sulfur dioxide']
# ressugar_d = data['residual sugar']
# brix_d.loc[0] = free_d.loc[0]
# brix_d

# %%
data['sg'] = a
test['sg'] = b

# %%
ressugar_d = data['residual sugar']
brix_d = pd.DataFrame()
brix_d['brix'] = brix_d
# brix_d = (alc_d*16.83-ressugar_d)/(9.982*data['free sulfur dioxide']*data['sg'])
brix_d = (alc_d-ressugar_d)/(data['free sulfur dioxide'])
ressugar_t = test['residual sugar']
brix_t = pd.DataFrame()
brix_t['brix'] = brix_t
# brix_t = (alc_t*16.83-ressugar_t)/(9.982*test['free sulfur dioxide']*test['sg'])
brix_t = (alc_t-ressugar_t)/(test['free sulfur dioxide'])

# %%
data['brix'] = brix_d
test['brix'] = brix_t

# %%
data = data.drop('index', axis = 1)
data = data.drop('sg', axis = 1)
data = data.drop('fixed acidity', axis = 1)
data = data.drop('residual sugar', axis = 1)
data = data.drop('alcohol', axis = 1)

# %%
test = test.drop('sg', axis = 1)
test = test.drop('fixed acidity', axis = 1)
test = test.drop('residual sugar', axis = 1)
test = test.drop('alcohol', axis = 1)

# %%
data.corr()
# Out:
#                        level_0  volatile acidity  citric acid  chlorides  \
# level_0               1.000000          0.026321     0.017413   0.031883
# volatile acidity      0.026321          1.000000    -0.399434   0.444007
# citric acid           0.017413         -0.399434     1.000000  -0.041280
# chlorides             0.031883          0.444007    -0.041280   1.000000
# free sulfur dioxide  -0.005944         -0.368488     0.157829  -0.238465
# total sulfur dioxide -0.013403         -0.412511     0.217217  -0.324797
# density              -0.005219          0.320278     0.071039   0.470450
# pH                    0.031133          0.267760    -0.341813   0.119682
# sulphates             0.017553          0.232548     0.031942   0.319468
# quality              -0.000782         -0.261417     0.109480  -0.221275
# brix                  0.019133          0.294230    -0.090253   0.247347
#
#                       free sulfur dioxide  total sulfur dioxide   density  \
# ...

# %%
test.corr()
# Out:
#                       volatile acidity  citric acid  chlorides  \
# volatile acidity              1.000000    -0.432103   0.344942
# citric acid                  -0.432103     1.000000   0.090382
# chlorides                     0.344942     0.090382   1.000000
# free sulfur dioxide          -0.342195     0.105643  -0.138841
# total sulfur dioxide         -0.444316     0.184849  -0.246629
# density                       0.235538     0.200611   0.362306
# pH                            0.267446    -0.396229  -0.024455
# sulphates                     0.254487     0.024964   0.338202
# quality                      -0.264250     0.067934  -0.217302
# brix                          0.369388    -0.101702   0.164015
#
#                       free sulfur dioxide  total sulfur dioxide   density  \
# volatile acidity                -0.342195             -0.444316  0.235538
# citric acid                      0.105643              0.184849  0.200611
# ...

# %%
#remove outliers
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# liststr = {'fixed acidity','citric acid','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH'
#            ,'sulphates','alcohol'}
# for feature in liststr:
#     upper_limit = data_new[feature].mean() + 2.5*data_new[feature].std()
#     lower_limit = data_new[feature].mean() - 2.5*data_new[feature].std()
    
#     # Remove the outliers, if any were specified
#     data_new = data_new.loc[(data_new[feature] <= upper_limit) & (data_new[feature] >= lower_limit)]
